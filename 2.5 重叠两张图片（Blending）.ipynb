# %%
import cv2 as cv
import matplotlib.pyplot as plt

img1 = cv.imread('./01_data/ml.png')
img2 = cv.imread('./01_data/opencv-logo.png')

# 因为两张图片尺寸不一致的话，不能使用addWeighted方法，
# 所以这里先调整两张图片的尺寸。
img1 = img1[:230, :186]
img2 = img2[:230, :186]

# addWeighted使用如下的公式进行计算：
# dst = img1*0.7 + img2*0.3 + 0
dst = cv.addWeighted(img1, 0.7, img2, 0.3, 0)


# plt.figure(figsize=(8, 3))

plt.subplot(1, 3, 1)
plt.imshow(img1[:,:,::-1])
plt.xticks([])
plt.yticks([])

plt.subplot(1, 3, 2)
plt.imshow(img2[:,:,::-1])
plt.xticks([])
plt.yticks([])

plt.subplot(1, 3, 3)
plt.imshow(dst[:,:,::-1])
plt.xticks([])
plt.yticks([])
plt.show()
